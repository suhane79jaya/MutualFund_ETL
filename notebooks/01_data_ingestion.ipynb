# %%
print("Details of fund_master dataset")
import pandas as pd

df = pd.read_csv("../data/raw/01_fund_master.csv")

print("Shape:", df.shape)
print(df.dtypes)

df.head()
# Out:
# Details of fund_master dataset
# Shape: (40, 15)
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
print("Details of nav_history dataset")
import pandas as pd

df = pd.read_csv("../data/raw/02_nav_history.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# Details of nav_history dataset
# ###Shape shows no of rows and columns in a dataset####
# Shape: (46000, 3)
# amfi_code      int64
# date          object
# nav          float64
# dtype: object
#    amfi_code        date      nav
# 0     119551  03-01-2022  54.3856
# 1     119551  04-01-2022  54.3474
# 2     119551  05-01-2022  54.6869
# 3     119551  06-01-2022  55.4550
# 4     119551  07-01-2022  55.3692

# %%
print("****Details of aum_by_fund_house dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/03_aum_by_fund_house.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of aum_by_fund_house dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (90, 5)
# date               object
# fund_house         object
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
print("****Details of monthly_sip_inflows dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/04_monthly_sip_inflows.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of monthly_sip_inflows dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (48, 6)
# month                         object
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# ...

# %%
print("****Details of category_inflows dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/05_category_inflows.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of category_inflows dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (144, 3)
# month                object
# category             object
# net_inflow_crore    float64
# dtype: object
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
print("****Details of industry_folio_count dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/06_industry_folio_count.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of industry_folio_count dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (21, 6)
# month                   object
# total_folios_crore     float64
# equity_folios_crore    float64
# debt_folios_crore      float64
# hybrid_folios_crore    float64
# others_folios_crore    float64
# dtype: object
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# ...

# %%
print("****Details of scheme_performance dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/07_scheme_performance.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of scheme_performance dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (40, 19)
# amfi_code               int64
# scheme_name            object
# fund_house             object
# category               object
# plan                   object
# return_1yr_pct        float64
# return_3yr_pct        float64
# return_5yr_pct        float64
# benchmark_3yr_pct     float64
# alpha                 float64
# beta                  float64
# sharpe_ratio          float64
# sortino_ratio         float64
# std_dev_ann_pct       float64
# max_drawdown_pct      float64
# aum_crore               int64
# expense_ratio_pct     float64
# morningstar_rating      int64
# risk_grade             object
# dtype: object
#    amfi_code                                   scheme_name       fund_house  \
# 0     119551     SBI Bluechip Fund - Regular Plan - Growth  SBI Mutual Fund
# 1     119552      SBI Bluechip Fund - Direct Plan - Growth  SBI Mutual Fund
# ...

# %%
print("****Details of investor_transactions dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/08_investor_transactions.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of investor_transactions dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (32778, 13)
# investor_id            object
# transaction_date       object
# amfi_code               int64
# transaction_type       object
# amount_inr              int64
# state                  object
# city                   object
# city_tier              object
# age_group              object
# gender                 object
# annual_income_lakh    float64
# payment_mode           object
# kyc_status             object
# dtype: object
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# ...

# %%
print("****Details of Portfolio Holdings dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/09_portfolio_holdings.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of Portfolio Holdings dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (322, 8)
# amfi_code              int64
# stock_symbol          object
# stock_name            object
# sector                object
# weight_pct           float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date        object
# dtype: object
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# ...

# %%
print("****Details of benchmark_indices dataset****")
import pandas as pd

df = pd.read_csv("../data/raw/10_benchmark_indices.csv")
print("###Shape shows no of rows and columns in a dataset####")
print("Shape:", df.shape)
print(df.dtypes)#It shows dataType of column names

df.head()#it shows the details of first five rows and columns
# Out:
# ****Details of benchmark_indices dataset****
# ###Shape shows no of rows and columns in a dataset####
# Shape: (8050, 3)
# date            object
# index_name      object
# close_value    float64
# dtype: object
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15
